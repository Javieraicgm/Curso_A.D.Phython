# %% [markdown]
# # Clase 10 Ejercicios

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('creditcard.csv')
df.head()
df['Class'] =df['Class'].astype('category')
df.describe(include = 'all')
# Out:
#                  Time            V1            V2            V3            V4  \
# count   284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# unique            NaN           NaN           NaN           NaN           NaN
# top               NaN           NaN           NaN           NaN           NaN
# freq              NaN           NaN           NaN           NaN           NaN
# mean     94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std      47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min          0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%      54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%      84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%     139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max     172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.linear_model import Perceptron
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import validation_curve
from sklearn.model_selection import learning_curve
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score

# %%
X = df.iloc[:,:-1].values
y = df.iloc[:,-1].values
X.shape
# Out:
# (284807, 30)

# %%
pipe_percep = make_pipeline(StandardScaler(),PCA(n_components=15),Perceptron(penalty='l2',random_state=1))

# %%
randomForest = RandomForestClassifier(criterion='gini',n_estimators=10,random_state=1 )

# %%
scoring = {'accuracy': 'balanced_accuracy',
            'precision': 'precision_weighted',
            'recall':'recall_weighted',
            'f1':'f1_weighted',
            'roc':'roc_weigthed'}

# %%
def Metrics(model):
    print(f'CV Error {np.mean(model.get())}  ')

# %%
Percep_scores = cross_val_score(estimator=pipe_percep,X = X,y = y,cv=10,n_jobs=-1)

# %% [markdown]
# # Desarrollo

# %%
# Metrics and analysis
from sklearn.metrics import roc_auc_score, matthews_corrcoef,cohen_kappa_score, make_scorer
from sklearn.model_selection import learning_curve
# Data modelation
from sklearn.model_selection import cross_validate
# Classifiers
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import Perceptron
# Dimension reduction
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
# Pipeline
from sklearn.pipeline import make_pipeline
import matplotlib.patheffects as PathEffects
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# 1. Lea el archivo local creditcard.csv

# %%
df = pd.read_csv('creditcard.csv')
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
#len(df[df['Class'] == 0])
print(f"Existen {len(df[df['Class'] == 0])} transacciones legitimas.")
print(f"Existen {len(df[df['Class'] == 1])} transacciones ilegitimas.")
# Out:
# Existen 284315 transacciones legitimas.
# Existen 492 transacciones ilegitimas.

# %% [markdown]
# 2. Genere una base de datos “de paso” que contenga 10.000 transacciones legítimas y todas las fraudulentas, luego, utilice TSNE para visualizar los clusters encontrados.

# %%
def cutDatabase(df: pd.DataFrame, n: int= -1, random_seed: int=14):
    #positive class
    dfTrue = df[df['Class'] == 1]
    if n == -1:
        n = len(dfTrue)
    #negative class
    dfFalse = df[df['Class'] == 0].sample(n = n, random_state= random_seed)
    #mix
    df_balanced = pd.concat([dfFalse,dfTrue]).sample(frac=1).reset_index(drop=True)
    
    return df_balanced.drop(['Class'], axis=1).values, df_balanced['Class'].values

# %%
x_pass, y_pass = cutDatabase(df,10000)

# %%
def plot_projection(x, colors):
    f = plt.figure(figsize=(8, 8))
    ax = plt.subplot(aspect='equal')
    for i in range(len(np.unique(y))):
        plt.scatter(x[colors == i, 0],x[colors == i, 1])
    for i in range(len(np.unique(y))):
        xtext, ytext = np.median(x[colors == i, :], axis=0)
        txt = ax.text(xtext, ytext, str(i), fontsize=24)
        txt.set_path_effects([PathEffects.Stroke(linewidth=5,foreground="w"),PathEffects.Normal()])
plt.show()

# %%
#Estadarizacion
x_pass = StandardScaler().fit_transform(x_pass)
#TSNE
x_pass_tsne = TSNE(n_components=2,init='pca',random_state=16273, learning_rate='auto',n_jobs=-1).fit_transform(x_pass)
plot_projection(x_pass_tsne, y_pass)
# Out:
# c:\Users\Javiera Carrasco\anaconda3\envs\ima539\lib\site-packages\sklearn\manifold\_t_sne.py:982: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(

# %% [markdown]
# 3. Instancie dos modelos: En primer lugar, una pipeline que realize una reducción de dimensión a 15 características utilizando PCA seguido de un Perceptrón y por otro lado un modelo Random Forest.

# %%
randomForest = RandomForestClassifier(criterion='gini', n_estimators= 10, random_state= 1, n_jobs= -1)

# %%
modelPerceptron = make_pipeline(StandardScaler(), PCA(n_components= 15), Perceptron(random_state= 1))

# %% [markdown]
# 4. Estime el desempeño de los modelos utilizando Cross Validation. Reporte los valores de Exactitud, Precisión, Recall, F1-Score, AUC, MCC y Kappa. ¿Son confiables estos resultados? ¿Tienen sentido?

# %%
def printMetrics(model,scoring):
    for k in scoring.keys():
        print(f'CV {k}: \t{np.mean(model.get(f"test_{k}")):.3f} +/- {np.std(model.get(f"test:{k}")):.3f}')

# %%
x, y = df.drop(['Class'], axis=1).values, df['Class'].values

# %%
scoring = {'accuracy' : 'balanced_accuracy',
           'precision' : 'precision_weighted',
           'recall' : 'recall_weighted',
           'f1' : 'f1_weighted',
           'roc' : make_scorer(roc_auc_score, average = 'weighted'),
           'mcc' : make_scorer(matthews_corrcoef),
           'kappa' : make_scorer(cohen_kappa_score)}

# %%
perceptronScores = cross_validate(modelPerceptron, x, y, scoring=scoring, cv=10, n_jobs=-1)
printMetrics(perceptronScores, scoring)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 2
#       1 perceptronScores = cross_validate(modelPerceptron, x, y, scoring=scoring, cv=10, n_jobs=-1)
# ----> 2 printMetrics(perceptronScores, scoring)
#
# Cell In[24], line 3, in printMetrics(model, scoring)
#       1 def printMetrics(model,scoring):
#       2     for k in scoring.keys():
# ----> 3         print(f'CV {k}: \t{np.mean(model.get(f"test_{k}")):.3f} +/- {np.std(model.get(f"test:{k}")):.3f}')
#
# File <__array_function__ internals>:180, in std(*args, **kwargs)
#
# File c:\Users\Javiera Carrasco\anaconda3\envs\ima539\lib\site-packages\numpy\core\fromnumeric.py:3573, in std(a, axis, dtype, out, ddof, keepdims, where)
#    3570     else:
#    3571         return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# -> 3573 return _methods._std(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# ...

# %%
scoring = {'accuracy' : 'accuracy',
           'precision' : 'precision',
           'recall' : 'recall',
           'f1' : 'f1',
           'roc' : 'roc_auc',
           'mcc' : make_scorer(matthews_corrcoef),
           'kappa' : make_scorer(cohen_kappa_score)}
